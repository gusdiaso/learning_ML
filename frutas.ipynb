# %%
import pandas as pd

df = pd.read_excel("data/dados_frutas.xlsx")
df
# Out:
#    Arredondada  Suculenta  Vermelha  Doce    Fruta
# 0            0          1         1     1  Morango
# 1            1          0         0     0    Limão
# 2            1          1         0     1     Pera
# 3            0          0         0     1   Banana
# 4            1          1         1     1   Cereja
# 5            1          1         1     0   Tomate
# 6            1          1         1     1     Maçã

# %%
from sklearn import tree

arvore = tree.DecisionTreeClassifier(random_state=42)

# %%
caracteristicas = ["Arredondada","Suculenta","Vermelha","Doce"]
y = df["Fruta"]
X = df[caracteristicas]

# %%
arvore.fit(X, y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
arvore.predict([[0,0,0,0]])
# Out:
# c:\Users\gusta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Banana'], dtype=object)

# %%
import matplotlib.pyplot as plt

plt.figure(dpi=200)
tree.plot_tree(arvore, feature_names=caracteristicas, class_names=arvore.classes_, filled=True)
# Out:
# [Text(0.4090909090909091, 0.875, 'Arredondada <= 0.5\ngini = 0.857\nsamples = 7\nvalue = [1, 1, 1, 1, 1, 1, 1]\nclass = Banana'),
#  Text(0.18181818181818182, 0.625, 'Suculenta <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1, 0, 0]\nclass = Banana'),
#  Text(0.09090909090909091, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Banana'),
#  Text(0.2727272727272727, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Morango'),
#  Text(0.6363636363636364, 0.625, 'Vermelha <= 0.5\ngini = 0.8\nsamples = 5\nvalue = [0, 1, 1, 1, 0, 1, 1]\nclass = Cereja'),
#  Text(0.45454545454545453, 0.375, 'Suculenta <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1, 0]\nclass = Limão'),
#  Text(0.36363636363636365, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Limão'),
#  Text(0.5454545454545454, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Pera'),
#  Text(0.8181818181818182, 0.375, 'Doce <= 0.5\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 0, 1, 0, 0, 1]\nclass = Cereja'),
#  Text(0.7272727272727273, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Tomate'),
#  Text(0.9090909090909091, 0.125, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0, 0]\nclass = Cereja')]

# %%
proba = arvore.predict_proba([[0,1,1,0]])[0]

pd.Series(proba, index=arvore.classes_)
# Out:
# c:\Users\gusta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# Banana     0.0
# Cereja     0.0
# Limão      0.0
# Maçã       0.0
# Morango    1.0
# Pera       0.0
# Tomate     0.0
# dtype: float64
